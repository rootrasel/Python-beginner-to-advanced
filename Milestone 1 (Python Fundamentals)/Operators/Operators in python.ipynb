# %% [markdown]
# a = 5
# b = 3
#
# print("Addition: ", a + b)
# print("Subtraction: ", a - b)
# print("Multiplication: ", a * b)
# print("Divide: ",  a / b)
# print("Fool Division: ", a // b)
# print("Exponanstiation: ", a ** b)

# %% [markdown]
# ### Relational operators

# %%
a = 7
b = 5

print("Equal: ", a == b)
print(" Not equla: ", a != b)
print("a greater then b: ", a > b)
print("a less then b: ", a < b)
print("a is greater then or equal: ", a >= b)
# Out:
# Equal:  False
#  Not equla:  True
# a greater then b:  True
# a less then b:  False
# a is greater then or equal:  True

# %% [markdown]
# ## Assignment Operators

# %%
a = 5
a += 2
a -= 3
a /= 2
a //= 2
a *= 10
a %= 3
a **= 3
a += 7


print("Value of a is: ", a)
# Out:
# Value of a is:  8.0

# %% [markdown]
# ## Logical Operators

# %%
a = 7
b = 5

# print("Results is: ", a > 3 and b < 6)
print("Results is: ", a == b)
# Out:
# Results is:  False

# %% [markdown]
# ## Membaership operators

# %%
text = "rootsofintelligence"

print("Results: ", 'i' not in text)
# Out:
# Results:  False

# %% [markdown]
# ## Identity Operators

# %%
b = a
c = [1, 2, 3]

print(a is b)       # True 
print(a is c)       # False 
print(a == c)       # True 
print(a is not c)   # True
# Out:
# True
# False
# False
# True
