# %%
with open("output.txt", "w") as f:
    f.write("Roots of intelligence \n")
    f.write("Programming is fun!")

with open("output.txt", "r") as f: 
    content = f.read()
    print(content)
# Out:
# Roots of intelligence
# Programming is fun!

# %%
age = int(input("Enter your age: "))
print(f'You are {age} years old.')
# Out:
# Enter your age:  25
# You are 25 years old.

# %%
height = float(input("Enter your height: "))
print(f'Your height is {height}.')
# Out:
# Enter your height:  5.4
# Your height is 5.4.

# %%
num = input("Enter your numbers separated by space: ")
num_list = [int(n) for n in num.split()]
print("Final list is", num_list)
# Out:
# Enter your numbers separated by space:  5 4 8 9
# Final list is [5, 4, 8, 9]

# %%
num = input("Enter your numbers separated by space: ").split()
print("Your finall list is", num)
# Out:
# Enter your numbers separated by space:  4 8 9 6
# Your finall list is ['4', '8', '9', '6']

# %%
numbers = list(map(int, input("Enter your numbers seperated by space: ").split()))
print("Your finall list is", numbers)
# Out:
# Enter your numbers seperated by space:  4 8 7 6 2 8 9 2 3
# Your finall list is [4, 8, 7, 6, 2, 8, 9, 2, 3]

# %%
from array import array

ar = array('i', map(int, input().split()))
print("Array: ", ar)
# Out:
# Enter space-separated integers:  4 8 9 6 5
# Array: array('i', [4, 8, 9, 6, 5])

# %%
from array import array

user_input = input("Enter space-separated integers: ")
int_list = list(map(int, user_input.split()))
ar = array('i', int_list)

print("Array:", ar)

# %% [markdown]
# ### Take Multiple Input in Python

# %%
a, b, c = map(int, input("Enter random three num: ").split()) 

print("1st number is: ", a)
print("2nd number is: ", b) 
print("3rd number is: ", c) 
d = a + b + c 
print("Add total 3 number is: ", d)
# Out:
# Enter random three num:  8 3 7
# 1st number is:  8
# 2nd number is:  3
# 3rd number is:  7
# Add total 3 number is:  18

# %%
a, b, c = map(int, input("Enter three numbers: ").split())

print("1st number is:", a)
print("2nd number is:", b)
print("3rd number is:", c)

d = a + b + c
print("Add total 3 number is:", d)
# Out:
# Enter three numbers:  7 6 4
# 1st number is: 7
# 2nd number is: 6
# 3rd number is: 4
# Add total 3 number is: 17

# %% [markdown]
# ### Using sep and end parameter

# %%
# Out:
# Roots@of Intelligence

# %%
# Out:
# 09-12-2025
# pratik@geeksforgeeks
